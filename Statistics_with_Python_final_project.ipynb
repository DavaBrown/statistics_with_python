# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kj/gmmdlcm97fn978p42ttyd5pr0000gp/T/ipykernel_65616/730555088.py in <module>
#       1 boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
# ----> 2 boston_df=pd.read_csv(boston_url)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
boston_df.boxplot(column='MEDV')
# Out:
# <AxesSubplot:>

# %%
boston_df.plot.bar(x='CHAS')
# Out:
# <AxesSubplot:xlabel='CHAS'>

# %%
boston_df.boxplot(column='MEDV', by='AGE')
# Out:
# <AxesSubplot:title={'center':'MEDV'}, xlabel='AGE'>

# %%
boston_df.plot.scatter(x='NOX',y='INDUS')
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='INDUS'>

# %%
boston_df.hist(column='PTRATIO')
# Out:
# array([[<AxesSubplot:title={'center':'PTRATIO'}>]], dtype=object)
